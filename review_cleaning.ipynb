# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os

# %%
df= pd.read_csv("reviews_kualalampur.csv")
df.columns=["rating","time","review","comment","hotel_id","hotel_name"]
df.to_csv("temp.csv")
df
# Out:
#       rating           time       review  \
# 0        NaN            NaN          NaN
# 1        NaN            NaN          NaN
# 2        NaN            NaN          NaN
# 3        NaN            NaN          NaN
# 4        NaN            NaN          NaN
# ...      ...            ...          ...
# 5435    10.0   January 2020  Exceptional
# 5436     9.6   January 2020  Exceptional
# 5437     5.4  December 2019         Fair
# 5438     2.0     April 2022    Very Poor
# 5439    10.0     March 2020  Exceptional
#
#                                               comment  hotel_id  \
# 0                                                 NaN         0
# 1                                                 NaN         0
# 2                                                 NaN         0
# 3                                                 NaN         0
# 4                                                 NaN         0
# ...                                               ...       ...
# ...

# %%
df.isnull().sum()
# Out:
# rating        3018
# time          3018
# review        3021
# comment       3021
# hotel_id         0
# hotel_name       0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
df=df.dropna(subset=['review'])
df['hotel_name'] = df['hotel_name'].str.replace('\n','')
df['hotel_name'] = df['hotel_name'].str.replace('Opens in new window','')
df
# Out:
# C:\Users\Anand\AppData\Local\Temp\ipykernel_5648\3472783109.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hotel_name'] = df['hotel_name'].str.replace('\n','')
# C:\Users\Anand\AppData\Local\Temp\ipykernel_5648\3472783109.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hotel_name'] = df['hotel_name'].str.replace('Opens in new window','')
#       rating           time  \
# 3018    10.0     April 2022
# 3019     8.0     April 2022
# 3020     8.0  February 2022
# ...

# %%
new = df["comment"].str.split("Disliked\n .", n = 4, expand = True)
df["comment1"]= new[0]
df["comment2"]= new[1]
# df.to_csv("temp.csv",index=False)
df['comment1'] = df['comment1'].str.replace('\n','')
df['comment1'] = df['comment1'].str.replace('Liked .','')
df.head()
# Out:
# C:\Users\Anand\AppData\Local\Temp\ipykernel_5648\3448872160.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["comment1"]= new[0]
# C:\Users\Anand\AppData\Local\Temp\ipykernel_5648\3448872160.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["comment2"]= new[1]
# C:\Users\Anand\AppData\Local\Temp\ipykernel_5648\3448872160.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>
